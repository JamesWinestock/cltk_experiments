# %%
from os import listdir
from os.path import isfile, join
import collections
import random

import gensim

from cltk.corpus.readers import get_corpus_reader
from cltk.tokenize.word import WordTokenizer
from cltk.stem.latin.j_v import JVReplacer

from pprint import pprint

# %%
latin_corpus = get_corpus_reader(corpus_name = 'latin_text_latin_library', language = 'latin')

# %%
print(latin_corpus)
# Out:
# <FilteredPlaintextCorpusReader in '/Users/jameswinestock 1/cltk_data/latin/text/latin_text_latin_library'>

# %%
files = latin_corpus.fileids()

# %%
livy = [file for file in files if 'livy' in file and 'per' not in file]

# %%
livy_words = latin_corpus.words(livy)

# %%
livy_words_list = list(livy_words)

# %%
print(livy_words_list[:10])
# Out:
# ['Livy', ':', 'Book', 'I', 'TITI', 'LIVI', 'AB', 'VRBE', 'CONDITA', 'LIBER']

# %%
from cltk.stop.latin import STOPS_LIST
from cltk.stem.lemma import LemmaReplacer

low_livy_list = [word.lower() for word in livy_words_list]
lemmatizer = LemmaReplacer('latin')
lematize_livy = [lemmatizer.lemmatize(word) for word in low_livy_list]
S = STOPS_LIST
flat_list = [item for sublist in lematize_livy for item in sublist]
livy_stops_removed = [w for w in flat_list if w not in STOPS_LIST]
junk = ['cn.', 't.', 'q.', "'", 'm.', 'p.', '[', ']', '.', ',', ' ', ':', ';', 'qui1', '-', 'que', '$', '%', '&','*','+', '-', '/', '<', '=', '>', '@', '^', '_',  '`', '{', '|', '}', '~', '?', '!', '«', '»']
livy_junk_removed = [w for w in livy_stops_removed if w not in junk]
clean_livy = livy_junk_removed

# %%
print(clean_livy[:10])
# Out:
# ['livy', 'book', 'eo1', 'titi', 'livi', 'vrbe', 'condio', 'libo1', 'eo1', '1']

# %%
word_tokenizer = WordTokenizer('latin')
replacer = JVReplacer()

# %%
# Preprocess texts

import html
import re
from cltk.stem.lemma import LemmaReplacer
lemmatizer = LemmaReplacer('latin')

def preprocess(text, remove_list=[]):

    if remove_list:
        for pattern in remove_list:
            text = re.sub(pattern, '', text)
    
    text = html.unescape(text) # Handle html entities
    text = re.sub(r'&nbsp;?', ' ',text) #&nbsp; stripped incorrectly in corpus?
    text = re.sub(r'\x00',' ',text) #Another space problem?
    
    text = text.lower()
    text = replacer.replace(text) #Normalize u/v & i/j

    
    
    punctuation ="\"#$%&\'()*+,-/:;<=>@[\]^_`{|}~.?!«»"
    translator = str.maketrans({key: " " for key in punctuation})
    text = text.translate(translator)
    
    
    translator = str.maketrans({key: " " for key in '0123456789'})
    text = text.translate(translator)
    
    text = re.sub('[ ]+',' ', text) # Remove double spaces
    text = re.sub('\s+\n+\s+','\n', text) # Remove double lines and trim spaces around new lines
    text = lemmatizer.lemmatize(text, return_string=True)
    
    return text

# %%
livy_raw = []

for file in livy:
    raw = latin_corpus.raw(file)
    start = raw.find('[ 1 ]')
    raw = raw[start:]
    raw = preprocess(raw, remove_list = [r'Livy', r'The Latin Library', r'The Classics Page'])
    livy_raw.append(raw.strip())

# %%
#print(livy_raw[1])

# %% [markdown]
# checkpoint text cleaned and lematized

# %%
import nltk
import numpy
import matplotlib
from nltk.probability import FreqDist

# %%
#livy_string = str(livy_raw)
livy_string = [str(para) for para in livy_raw]

# %%
print(livy_string[:10])
# Out:
# ['1 jam primus omne sero1 consto troia capio in ceter saevio edo1 troianos duo aeneus antenorique et vetustus jus hospitium et quia pax reddo helenae semper auctoro sum1 omne jus bellus achiuos abstineo casus1 deinde varius1 antenorem cum multitudo ex-neo1 qui1 seditio ex paphlagonia pello et sedeo et dux rego pylaemene ad troiam amitto quaero venio in intimus mare hadriatici sinum euganeisque qui1 inter mare alpesque incolo1 pello ex-neo1 troianosque eo1 teneo terra et in qui1 primus egredior sum1 locus troia voco pagus indo troiano nomen edo1 gens universus ueneti appello aeneus ab similis clades domo profugus sed ad magnus res initio duco for primus in macedoniam venio indo in sicilio quaero sedeo defero ab sicilia classis ad laurentem ager teneo troia et hic loco nomen edo1 ibi egredior troiani ut qui1 ab immensus prope error nihil praeter armo et navo supersum cum praeda ex ager ago latinus rex aboriginesque qui1 tum is teneo loco ad arceo vis advena armo ex urbs atque ager concurro duplex indo fama edo1 alius2 proelio vinco latinum pax cum aeneus deinde affinitas jungo trado alius2 cum instruo acieris consto prior signo caneo procedo latinum inter primoris dux advena evoco ad colloquium perconto deinde qui1 mortalis edo1 unde aut quis1 cado proficio domo quis1 quaero in ager laurentinum exeo postquam audio multitudo troianos edo1 dux aeneus filius anchisae et venio cremo patrium domo profugus sedo condo urbs locus quaero et nobilitas admiror gens vir et animus vel bellus vel pax paro1 dexter do fides1 sum1 amicitia sancio indo foedus1 ictus2 inter duco inter exerceo salutatio facio aeneus apud latinum sum1 in hospitium ibi latinum apud Penates deus domesticus publico adjungo foedus1 filia aeneus in matrimonium do is reor utique2 troianis spes ad-firmo tandem stabilio certo2 sedeo finio error oppidum condo aeneus ab nomen uxor lauinium appello brevis stirps quoque virilis ex novo matrimonium sum1 qui1 ascanium pareo dico2 nomen 2 bellus deinde aborigines troianique simul peto turnus rex rutulorum qui1 paciscor lauinia ante advenio aeneus sum1 praefero sui advena aeger patior simul aeneus latino bellus infero neuter acieris laeto ex eo1 certamen abeo vinco rutuli victor1 aborigines troianique dux latinum amitto indo turnus rutulique diffido res ad floreo ops1 etruscorum mezentiumque rex is confugio qui1 caere opulentus tum oppidum imperito jam indo ab initio minimus laetus1 novus origo1 urbs et tum nimius multus qui1 sero1 tueor edo1 accolo res troianam cresco reor haud gravatim socio armo rutula jungo aeneus adverro tantus bellus terror ut animus aboriginum sui concilio neque sub idem jus solus1 sed etiam nomen omnes edo1 latinos uter gens appello neque deinde aborigines troianis studium atque fido erga rex aeneus cedo1 fretus hic animus coalesco in dies magus2 duo populus1 aeneus quisquam tantus ops1 etruria sum1 ut jam non terra solus1 sed mare etiam per totus1 italiae longitudo ab alpibus ad fretus1 siculum fama nomen suo impleo tamen cum moenia1 bellus propulso possum in acies copia1 educo1 secundus1 indo proelium latinis aeneus etiam ulter opus1 mortalis sum1 sino edo1 quicumque is dico2 jus for edo1 supo numicum flumen iouem indigeto appello 3 nondum maturus imperium ascanius aeneus filius sum1 tamen is imperium is ad pubes1 aetas incolumis maneo tantisper tutela muliebri—tanta indoles in lauinia erat—res latino et regnum avitus1 paternus puer sto haud ambigam—quis enim res tam vetus pro1 certo2 ad-firmo —hicine sum1 ascanius an magnus qui1 hic creusa mater ilium incolumis nascor como1 indo paternus fuga qui1 iulus1 idem iulia gens auctoro nomen suo nuncupo eo1 ascanius ubicumque et quicumque mater genitus—certe nascor aeneus constat—abundante lauinii multitudo floreo jam ut tum reor sum1 atque opulentus urbs mater sive noverca relinquo novus ipse alius2 sub albano mons condo qui1 ab sino porrigo1 in dorsum urbs longus album appello inter lauinium et alba1 longus colonia1 deduco triginta ferme intersum annus tantus  ...

# %%
#tokens = nltk.word_tokenize(livy_string)
tokens = [nltk.word_tokenize(para) for para in livy_string]

# %%
print(tokens[34])
# Out:
# ['1', 'sequor', 'hic', 'annus', 'nobilis', 'clades', 'romana', 'caudina', 'pax', 't', 'ueturio', 'caluino', 'sp', 'postumio', 'consul', 'samnites', 'eo1', 'adnato', 'imperator', 'c', 'pons', 'herenni', 'filius', 'habeo', 'pater', 'longus', 'prudens', 'nascor', 'primus', 'ipse', 'bellator', 'dux', 'eo1', 'ubi', 'lego1', 'qui1', 'ad', 'dedo', 'reor', 'mitto', 'sum1', 'pax', 'inficio', 'redeo', 'neo1', 'nihil', 'ago', 'inquam', 'hic', 'legatio', 'censeo1', 'expio', 'edo1', 'quisquis', 'ex', 'foedo', 'rumpo', 'ira', 'in', 'nos', 'caelestis', 'sum1', 'sero1', 'scio', 'quicumque', 'dives', 'chordus1', 'sum1', 'subigo', 'nos', 'ad', 'necessitas', 'dedo', 'reor', 'qui1', 'ab', 'nos', 'ex', 'foedo', 'repeto', 'sum1', 'is', 'non', 'sum1', 'chordus1', 'tam', 'superbus', 'ab', 'romanis', 'foedo', 'expiatio', 'sperno', 'quis1', 'enim', 'ulter', 'fio', 'ad', 'placo', 'deus', 'mitigo', 'homo', 'possum', 'qui1', 'qui1', 'nos', 'facio', 'reor', 'hostis', 'in', 'praeda', 'capio', 'qui1', 'bellus', 'jus', 'noster', 'video', 'remitto', 'auctoro', 'bellus', 'quia', 'vivus', 'non', 'possum', 'perfungor', 'jam', 'for', 'dedo', 'bonus', 'is', 'neo1', 'quis1', 'ex', 'contagio', 'noxa', 'remaneo', 'penis', 'nos', 'romam', 'porto', 'quis1', 'ulter', 'tu', 'romane', 'quis1', 
ueor', 'tantus', 'for', 'longus', 'alter', 'per', 'furcula', 'caudinas', 'brevis', 'sed', 'ito', 'nascor', 'locus', 'edo1', 'saltus1', 'duo', 'alo', 'angustus', 'siluosique', 'sum1', 'mons', 'circo', 'perpetuus', 'inter', 'sui', 'jungo', 'jaceo', 'inter', 'is', 'sero1', 'pateo', 'claudo', 'in', 'medius', 'campus1', 'herbidus', 'aquosus', 'per', 'qui1', 'medius', 'ito', 'edo1', 'sed', 'antequam', 'venio', 'ad', ...

# %%
mytext = nltk.Text(livy_raw)

# %%
#print(mytext[:10])

# %%
from pprint import pprint
from gensim import corpora
from collections import defaultdict
from gensim.corpora import Dictionary

# %%
dictionary = corpora.Dictionary(tokens)

# %%
print(dictionary)
# Out:
# Dictionary(15082 unique tokens: ['1', '10', '11', '12', '13']...)

# %%
print(dictionary.token2id)
# Out:
# {'1': 0, '10': 1, '11': 2, '12': 3, '13': 4, '14': 5, '15': 6, '16': 7, '17': 8, '18': 9, '19': 10, '2': 11, '20': 12, '21': 13, '22': 14, '23': 15, '24': 16, '25': 17, '26': 18, '27': 19, '28': 20, '29': 21, '3': 22, '30': 23, '31': 24, '32': 25, '33': 26, '34': 27, '35': 28, '36': 29, '37': 30, '38': 31, '39': 32, '4': 33, '40': 34, '41': 35, '42': 36, '43': 37, '44': 38, '45': 39, '46': 40, '47': 41, '48': 42, '49': 43, '5': 44, '50': 45, '51': 46, '52': 47, '53': 48, '54': 49, '55': 50, '56': 51, '57': 52, '58': 53, '59': 54, '6': 55, '60': 56, '7': 57, '8': 58, '9': 59, 'Hercules': 60, 'Penates': 61, 'a-migro': 62, 'a-sum1': 63, 'ab': 64, 'abdo': 65, 'abduco': 66, 'abeo': 67, 'aberat—consequi': 68, 'abhorreo': 69, 'abigo': 70, 'ablego': 71, 'abnuo': 72, 'aboleuit': 73, 'aborigines': 74, 'aboriginesque': 75, 'aboriginum': 76, 'abrogo': 77, 'absentiumque': 78, 'absolvo': 79, 'absonus': 80, 'abstergeo': 81, 'abstineo': 82, 'absum': 83, 'accedo': 84, 'accendo2': 85, 'accingo': 86, 'accio': 87, 'accipio': 88, 'accola': 89, 'accolo': 90, 'accuso': 91, 'acer': 92, 'achiuos': 93, 'acieris': 94, 'acies': 95, 'acquiro': 96, 'actiacum': 97, 'ad': 98, 'ad-cresco': 99, 'ad-edo1': 100, 'ad-firmo': 101, 'ad-probo': 102, 'ad-scisco': 103, 'ad-sentio': 104, 'ad-sumo': 105, 'adaequo': 106, 'adclarassis': 107, 'addico': 108, 'addo': 109, 'adduco': 110, 'adeo1': 111, 'adeptus': 112, 'adequito': 113, 'adfectandi': 114, 'adfectare': 115, 'adfectet': 116, 'adhibeo': 117, 'adhortor': 118, 'adicio': 119, 'adimo': 120, 'adipiscamur': 121, 'adipiscendi': 122, 'adjectio':